# %%
import numpy as np
# %matplotlib inline
from matplotlib.image import imread
from PIL import Image

image = imread("yellowPath3.jpg")

image = Image.fromarray(image, 'RGB').convert('L')
image.save('my.png')
display(image)
# Out:
# <PIL.Image.Image image mode=L size=160x120>
