# %% [markdown]
# # Tutorial 4 (part 2)
#
# This tutorial classifies images from the RGBD sensor. The first step is to read the labels.txt file. **Please download that file from LEARN and upload it to the robot before running this code.** You also need to download the pretrained model ('alexnet-owt-4df8aa71.pth') and upload it to the robot. The model can be downloaded from the following link https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth

# %%
#open the txt file and read object categories.
f = open("labels.txt", "r") 
labels = []
for x in f: # read the txt file line by line
    labels.append(x.split(':')[1]) #add it to the list
print(len(labels))
# Out:
# 1000

# %% [markdown]
# Run the following code to capture image data from the RGBD sensor

# %%
#use traitlets and widgets to display the image in Jupyter Notebook
import traitlets
from traitlets.config.configurable import SingletonConfigurable

#use opencv to covert the depth image to RGB image for displaying purpose
import cv2
import numpy as np

#using realsense to capture the color and depth image
import pyrealsense2 as rs

#multi-threading is used to capture the image in real time performance
import threading

predict_id = 0
class Camera(SingletonConfigurable):
    
    #this changing of this value will be captured by traitlets
    color_value = traitlets.Any()
    
    def __init__(self):
        super(Camera, self).__init__()
        
        #configure the color and depth sensor
        self.pipeline = rs.pipeline()
        self.configuration = rs.config()  
        
        #set resolution for the color camera
        self.color_width = 640
        self.color_height = 480
        self.color_fps = 30
        self.configuration.enable_stream(rs.stream.color, self.color_width, self.color_height, rs.format.bgr8, self.color_fps)

        #set resolution for the depth camera
        self.depth_width = 640
        self.depth_height = 480
        self.depth_fps = 30
        self.configuration.enable_stream(rs.stream.depth, self.depth_width, self.depth_height, rs.format.z16, self.depth_fps)

        #flag to control the thread
        self.thread_runnning_flag = False
        
        #start the RGBD sensor
        self.pipeline.start(self.configuration)
        self.pipeline_started = True
        frames = self.pipeline.wait_for_frames()

        #start capture the first color image
        color_frame = frames.get_color_frame()   
        image = np.asanyarray(color_frame.get_data())
        self.color_value = image

        #start capture the first depth image
        depth_frame = frames.get_depth_frame()           
        depth_image = np.asanyarray(depth_frame.get_data())
        depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)
        self.depth_value = depth_colormap   

class Camera(SingletonConfigurable):
    # Other methods and attributes remain the same
    
    def _capture_frames(self):
        # Initialize human detection cascade classifiers
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        fullbody_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_fullbody.xml')

        while(self.thread_runnning_flag==True):
            frames = self.pipeline.wait_for_frames()
            color_frame = frames.get_color_frame()
            image = np.asanyarray(color_frame.get_data())

            # Perform human detection
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            bodies = fullbody_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

            # Draw bounding boxes around detected humans
            for (x,y,w,h) in faces:
                cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
            for (x,y,w,h) in bodies:
                cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

            self.color_value = image
            # Continue with depth image processing and displaying

    
    def start(self): #start the data capture thread
        if self.thread_runnning_flag == False: #only process if no thread is running yet
            self.thread_runnning_flag=True #flag to control the operation of the _capture_frames function
            self.thread = threading.Thread(target=self._capture_frames) #link thread with the function
            self.thread.start() #start the thread

    def stop(self): #stop the data capture thread
        if self.thread_runnning_flag == True:
            self.thread_runnning_flag = False #exit the while loop in the _capture_frames
            self.thread.join() #wait the exiting of the thread       

def bgr8_to_jpeg(value):#convert numpy array to jpeg coded data for displaying 
    return bytes(cv2.imencode('.jpg',value)[1])

#create a camera object
camera = Camera.instance()
camera.start() # start capturing the data

# %% [markdown]
# Run the following code to perform classification and display the images

# %%
#The pytorch platform is used in this tutorial
import torch
import torchvision
import torch.nn as nn
import cv2
import numpy as np

# the following AlexNet model is defined by torchvision
class AlexNet(nn.Module):

    def __init__(self, num_classes=1000):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

model = AlexNet()
model.load_state_dict(torch.load('alexnet-owt-4df8aa71.pth'))
# 'alexnet-owt-4df8aa71.pth' is the pretrained model, it can be downloaded from the following link
# https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth
# this model should be placed under the same folder of this file

#We use GPU for classification 
device = torch.device('cuda')
model = model.to(device)


import ipywidgets.widgets as widgets
from IPython.display import display, HTML
import sys

#create widgets for the displaying of the image
display_color = widgets.Image(format='jpeg', width='45%') #determine the width of the color image
display_depth = widgets.Image(format='jpeg', width='45%')  #determine the width of the depth image
layout=widgets.Layout(width='100%')

sidebyside = widgets.HBox([display_color, display_depth],layout=layout) #horizontal 
display(sidebyside) #display the widget

#callback function, invoked when traitlets detects the changing of the color image
def process(change):
    
    image = change['new'] #retrieve data from the input dict
    display_color.value = bgr8_to_jpeg(cv2.resize(image,(160,120)))
    display_depth.value = bgr8_to_jpeg(cv2.resize(camera.depth_value,(160,120)))

#processing({'new': camera.color_value})
#the camera.observe function will monitor the color_value variable. If this value changes, the processing function will be excuted.
camera.observe(process, names='color_value')


#the following code will classify the image and measure the time 
while (1):
    t1 = cv2.getTickCount() 
    imgsized= cv2.resize(camera.color_value,(224,224)) #resize the image
    x = cv2.cvtColor(imgsized, cv2.COLOR_BGR2RGB) #convert to RGB as required by the model
    x = x.transpose((2, 0, 1)) #swith the image channels
    x = torch.from_numpy(x).float() #convert to type float
    mean = 255.0 * np.array([0.485, 0.456, 0.406]) #mean value
    stdev = 255.0 * np.array([0.229, 0.224, 0.225]) # for the nomalization of the input image
    normalize = torchvision.transforms.Normalize(mean, stdev)
    x = normalize(x)
    x = x.to(device)# send the data to GPU device
    x = x[None, ...] # increase the image dimension, the model takes a batch of images and the batch size is 1
    output = model(x) #classfy the images
    predict_id = output.max(1, keepdim=True)[1].item() #get the label
    print('id ', predict_id," prediction time ", (cv2.getTickCount()-t1)/cv2.getTickFrequency())
# Out:
# HBox(children=(Image(value=b'', format='jpeg', width='45%'), Image(value=b'', format='jpeg', width='45%')), la…
# id  256  prediction time  12.681661722
# id  527  prediction time  0.105745472
# id  747  prediction time  0.112847599
# id  527  prediction time  0.068712513
# id  747  prediction time  0.073490875
# id  799  prediction time  0.069631508
# id  422  prediction time  0.067404565
# id  527  prediction time  0.071383843
# id  598  prediction time  0.064851126
# id  598  prediction time  0.065635022
# id  799  prediction time  0.054757317
# id  527  prediction time  0.068927838
# id  799  prediction time  0.091001991
# id  527  prediction time  0.044868245
# id  799  prediction time  0.048860686
# id  799  prediction time  0.070471982
# id  799  prediction time  0.067426506
# id  799  prediction time  0.065014041
# id  527  prediction time  0.053237913
# id  553  prediction time  0.041823289
# id  747  prediction time  0.070320837
# id  569  prediction time  0.051445387
# id  527  prediction time  0.039274926
# id  527  prediction time  0.050431282
# id  707  prediction time  0.048493548
# id  799  prediction time  0.06003266
# id  799  prediction time  0.058194456
# id  799  prediction time  0.04256962
# id  527  prediction time  0.057219573
# id  527  prediction time  0.05197975
# id  526  prediction time  0.046967527
# id  527  prediction time  0.050959868
# id  527  prediction time  0.050114776
# id  527  prediction time  0.063978491
# id  799  prediction time  0.04557911
# id  799  prediction time  0.046960184
# id  799  prediction time  0.039859293
# id  799  prediction time  0.04981754
# id  527  prediction time  0.054625964
# id  799  prediction time  0.058032531
# id  527  prediction time  0.046139466
# id  527  prediction time  0.05672029
# id  527  prediction time  0.044967958
# id  760  prediction time  0.04993654
# id  598  prediction time  0.044451351
# id  527  prediction time  0.060303593
# id  598  prediction time  0.072632236
# id  799  prediction time  0.047107462
# id  799  prediction time  0.052184167
# id  799  prediction time  0.058682417
# id  756  prediction time  0.088469218
# id  799  prediction time  0.062589345
# id  799  prediction time  0.052236145
# id  527  prediction time  0.061902947
# id  598  prediction time  0.062194558
# id  756  prediction time  0.065831543
# id  756  prediction time  0.061736595
# id  799  prediction time  0.068225958
# id  527  prediction time  0.069170461
# id  527  prediction time  0.070633673
# id  527  prediction time  0.050314076
# id  527  prediction time  0.045236221
# id  598  prediction time  0.0581382
# id  675  prediction time  0.055124122
# id  799  prediction time  0.054705637
# id  760  prediction time  0.068029069
# id  527  prediction time  0.053055709
# id  598  prediction time  0.063070483
# id  799  prediction time  0.037284651
# id  527  prediction time  0.056630823
# id  664  prediction time  0.052575767
# id  526  prediction time  0.0521052
# id  527  prediction time  0.048023791
# id  527  prediction time  0.048850969
# id  526  prediction time  0.052530872
# id  527  prediction time  0.051577992
# id  527  prediction time  0.05780554
# id  526  prediction time  0.056374514
# id  799  prediction time  0.046506501
# id  799  prediction time  0.055220517
# id  527  prediction time  0.065147851
# id  799  prediction time  0.046439211
# id  527  prediction time  0.052768566
# id  756  prediction time  0.042224467
# id  760  prediction time  0.064457859
# id  760  prediction time  0.054646825
# id  882  prediction time  0.061713828
# id  553  prediction time  0.058231055
# id  747  prediction time  0.049940576
# id  799  prediction time  0.052199197
# id  799  prediction time  0.080272315
# id  760  prediction time  0.056895446
# id  882  prediction time  0.051516504
# id  756  prediction time  0.059477855
# id  747  prediction time  0.063879161
# id  882  prediction time  0.043059801
# id  882  prediction time  0.052742822
# id  882  prediction time  0.052739125
# id  608  prediction time  0.045525347
# id  480  prediction time  0.076815794
# id  747  prediction time  0.062364959
# id  747  prediction time  0.054831498
# id  747  prediction time  0.041533254
# id  747  prediction time  0.044232132
# id  799  prediction time  0.049321557
# id  747  prediction time  0.058221201
# id  785  prediction time  0.056164973
# id  747  prediction time  0.046862937
# id  675  prediction time  0.055163786
# id  920  prediction time  0.050386962
# id  882  prediction time  0.054271037
# id  882  prediction time  0.066741572
# id  882  prediction time  0.051190633
# id  675  prediction time  0.052823377
# id  480  prediction time  0.06046653
# id  799  prediction time  0.068579834
# id  675  prediction time  0.052000521
# id  747  prediction time  0.048548889
# id  812  prediction time  0.058878108
# id  756  prediction time  0.040723602
# id  675  prediction time  0.059942942
# id  422  prediction time  0.055277363
# id  439  prediction time  0.060203511
# id  747  prediction time  0.049082529
# id  799  prediction time  0.060434603
# id  675  prediction time  0.068084683
# id  747  prediction time  0.047024581
# id  747  prediction time  0.050656108
# id  747  prediction time  0.05254252
# id  882  prediction time  0.05086546
# id  882  prediction time  0.066502501
# id  480  prediction time  0.052154458
# id  747  prediction time  0.047846634
# id  882  prediction time  0.046142171
# id  747  prediction time  0.054801985
# id  675  prediction time  0.061907908
# id  675  prediction time  0.04019207
# id  675  prediction time  0.052542631
# id  675  prediction time  0.086407731
# id  675  prediction time  0.050505255
# id  670  prediction time  0.054533759
# id  705  prediction time  0.060257871
# id  756  prediction time  0.067059787
# id  705  prediction time  0.065167097
# id  675  prediction time  0.054156366
# id  882  prediction time  0.046474166
# id  670  prediction time  0.056336796
# id  675  prediction time  0.064680368
# id  675  prediction time  0.061024619
# id  882  prediction time  0.055130817
# id  675  prediction time  0.05170293
# id  882  prediction time  0.055006339
# id  675  prediction time  0.065595568
# id  756  prediction time  0.041743382
# id  422  prediction time  0.052258967
# id  756  prediction time  0.055207431
# id  882  prediction time  0.044928199
# id  675  prediction time  0.049754926
# id  422  prediction time  0.055423783
# id  756  prediction time  0.053994473
# id  882  prediction time  0.041217449
# id  675  prediction time  0.057708919
# id  675  prediction time  0.039052833
# id  569  prediction time  0.048788687
# id  756  prediction time  0.045751653
# id  882  prediction time  0.054720747
# id  675  prediction time  0.049264021
# id  756  prediction time  0.070024057
# id  675  prediction time  0.057931918
# id  675  prediction time  0.048515589
# id  882  prediction time  0.065701124
# id  882  prediction time  0.06167845
# id  422  prediction time  0.060100754
# id  422  prediction time  0.046939404
# id  675  prediction time  0.05745187
# id  675  prediction time  0.047398672
# id  675  prediction time  0.059049825
# id  747  prediction time  0.062260112
# id  756  prediction time  0.056145839
# id  882  prediction time  0.06351734
# id  480  prediction time  0.055150326
# id  882  prediction time  0.06272045
# id  675  prediction time  0.054806347
# id  705  prediction time  0.044442
# id  812  prediction time  0.057701584
# id  675  prediction time  0.046624275
# id  920  prediction time  0.067574269
# id  812  prediction time  0.07578207
# id  799  prediction time  0.047892754
# id  675  prediction time  0.086058501
# id  756  prediction time  0.049998728
# id  675  prediction time  0.054157342
# id  756  prediction time  0.057821375
# id  834  prediction time  0.067601977
# id  799  prediction time  0.059582925
# id  882  prediction time  0.078574704
# id  675  prediction time  0.056672322
# id  670  prediction time  0.052984976
# id  882  prediction time  0.052346807
# id  756  prediction time  0.055425588
# id  675  prediction time  0.049088967
# id  480  prediction time  0.075381953
# id  675  prediction time  0.054679343
# id  675  prediction time  0.052771024
# id  675  prediction time  0.040185646
# id  705  prediction time  0.051016141
# id  705  prediction time  0.055953605
# id  422  prediction time  0.048325014
# id  480  prediction time  0.05679912
# id  675  prediction time  0.058716553
# id  422  prediction time  0.044840196
# id  422  prediction time  0.058289942
# id  422  prediction time  0.048095901
# id  675  prediction time  0.060366958
# id  705  prediction time  0.053114094
# id  675  prediction time  0.050741678
# id  756  prediction time  0.058525487
# id  675  prediction time  0.059886364
# id  705  prediction time  0.057526119
# id  705  prediction time  0.047175201
# id  414  prediction time  0.089334288
# id  414  prediction time  0.069367081
# id  920  prediction time  0.068102975
# id  199  prediction time  0.061888121
# id  747  prediction time  0.057045601
# id  834  prediction time  0.045853907
# id  583  prediction time  0.057991689
# id  799  prediction time  0.061817496
# id  505  prediction time  0.04793582
# id  799  prediction time  0.053143337
# id  569  prediction time  0.057900127
# id  882  prediction time  0.050394345
# id  747  prediction time  0.062547101
# id  882  prediction time  0.06633791
# id  598  prediction time  0.055553604
# id  422  prediction time  0.059240247
# id  747  prediction time  0.041050468
# id  799  prediction time  0.054511475
# id  598  prediction time  0.037564656
# id  527  prediction time  0.056835784
# id  553  prediction time  0.059212331
# id  527  prediction time  0.060766591
# id  527  prediction time  0.053448357
# id  747  prediction time  0.053159244
# id  799  prediction time  0.05614459
# id  747  prediction time  0.051758004
# id  747  prediction time  0.065975725
# id  713  prediction time  0.059782431
# id  799  prediction time  0.044115135
# id  799  prediction time  0.050708068
# id  598  prediction time  0.058081476
# id  527  prediction time  0.057253981
# id  527  prediction time  0.059297041
# id  799  prediction time  0.058175694
# id  799  prediction time  0.055344618
# id  799  prediction time  0.064693363
# id  527  prediction time  0.053025308
# id  527  prediction time  0.064738363
# id  527  prediction time  0.077949534
# id  527  prediction time  0.049436475
# id  799  prediction time  0.044593483
# id  799  prediction time  0.057106221
# id  799  prediction time  0.040580175
# id  760  prediction time  0.064874977
# id  598  prediction time  0.047608986
# id  799  prediction time  0.050503605
# id  799  prediction time  0.061383079
# id  799  prediction time  0.04549136
# id  799  prediction time  0.071313872
# id  527  prediction time  0.064289171
# id  799  prediction time  0.054831881
# id  747  prediction time  0.051970854
# id  799  prediction time  0.054471154
# id  598  prediction time  0.058932378
# id  799  prediction time  0.058226445
# id  527  prediction time  0.046653385
# id  799  prediction time  0.06132424
# id  756  prediction time  0.060234194
# id  799  prediction time  0.056332445
# id  527  prediction time  0.04133456
# id  527  prediction time  0.05362319
# id  598  prediction time  0.058006915
# id  527  prediction time  0.052110021
# id  799  prediction time  0.061729602
# id  598  prediction time  0.044141903
# id  799  prediction time  0.055931685
# id  598  prediction time  0.037732822
# id  527  prediction time  0.061104783
# id  527  prediction time  0.051052909
# id  527  prediction time  0.063225449
# id  598  prediction time  0.06557601
# id  799  prediction time  0.051645718
# id  598  prediction time  0.064894087
# id  799  prediction time  0.047016003
# id  527  prediction time  0.04689866
# id  760  prediction time  0.038465162
# id  527  prediction time  0.052691754
# id  799  prediction time  0.042913472
# id  527  prediction time  0.056486995
# id  527  prediction time  0.047059336
# id  747  prediction time  0.051137024
# id  527  prediction time  0.056380641
# id  905  prediction time  0.050829893
# id  527  prediction time  0.059628456
# id  598  prediction time  0.058237474
# id  760  prediction time  0.060683711
# id  799  prediction time  0.048828197
# id  799  prediction time  0.058140755
# id  799  prediction time  0.05718977
# id  799  prediction time  0.043815513
# id  598  prediction time  0.046790707
# id  598  prediction time  0.047410131
# id  799  prediction time  0.066091341
# id  598  prediction time  0.059907414
# id  422  prediction time  0.046973415
# id  561  prediction time  0.055468581
# id  799  prediction time  0.051439434
# id  598  prediction time  0.052766355
# id  799  prediction time  0.064259684
# id  527  prediction time  0.060070798
# id  747  prediction time  0.046697644
# id  527  prediction time  0.052815225
# id  527  prediction time  0.069044994
# id  799  prediction time  0.072293885
# id  920  prediction time  0.048277173
# id  799  prediction time  0.061463987
# id  799  prediction time  0.045854633
# id  527  prediction time  0.053269858
# id  526  prediction time  0.067321513
# id  527  prediction time  0.053015849
# id  527  prediction time  0.044766877
# id  799  prediction time  0.05342892
# id  905  prediction time  0.062178515
# id  882  prediction time  0.050960754
# id  756  prediction time  0.053383087
# id  598  prediction time  0.065141522
# id  799  prediction time  0.075805066
# id  799  prediction time  0.056463603
# id  799  prediction time  0.065036333
# id  799  prediction time  0.054814138
# id  799  prediction time  0.048295468
# id  799  prediction time  0.050473844
# id  527  prediction time  0.047076879
# id  799  prediction time  0.06915668
# id  526  prediction time  0.057615584
# id  799  prediction time  0.075489465
# id  527  prediction time  0.072259531
# id  527  prediction time  0.042431692
# id  799  prediction time  0.065432425
# id  527  prediction time  0.053418363
# id  527  prediction time  0.054584607
# id  799  prediction time  0.049508952
# id  747  prediction time  0.067117731
# id  799  prediction time  0.053195395
# id  799  prediction time  0.05752841
# id  527  prediction time  0.055764878
# id  673  prediction time  0.065137027
# id  475  prediction time  0.054457852
# id  530  prediction time  0.038542395
# id  664  prediction time  0.042351131
# id  598  prediction time  0.051890466
# id  799  prediction time  0.042371651
# id  598  prediction time  0.054635091
# id  598  prediction time  0.045717262
# id  831  prediction time  0.04928954
# id  831  prediction time  0.045429399
# id  929  prediction time  0.046806946
# id  153  prediction time  0.049964485
# id  720  prediction time  0.046093198
# id  723  prediction time  0.04657554
# id  96  prediction time  0.039874109
# id  723  prediction time  0.042981649
# id  845  prediction time  0.04202759
# id  845  prediction time  0.050665992
# id  851  prediction time  0.054417181
# id  527  prediction time  0.047796068
# id  527  prediction time  0.041914215
# id  745  prediction time  0.050301423
# id  413  prediction time  0.049349708
# id  413  prediction time  0.050200434
# id  498  prediction time  0.044570976
# id  664  prediction time  0.044642174
# id  527  prediction time  0.043026868
# id  527  prediction time  0.03724715
# id  527  prediction time  0.041899059
# id  527  prediction time  0.046627948
# id  413  prediction time  0.042224631
# id  527  prediction time  0.038209334
# id  527  prediction time  0.041410363
# id  527  prediction time  0.048508409
# id  527  prediction time  0.037721731
# id  527  prediction time  0.051176212
# id  527  prediction time  0.041358228
# id  527  prediction time  0.045555868
# id  620  prediction time  0.042866764
# id  527  prediction time  0.046693208
# id  620  prediction time  0.045842747
# id  620  prediction time  0.038872101
# id  526  prediction time  0.04920196
# id  742  prediction time  0.041267717
# id  742  prediction time  0.045087912
# id  605  prediction time  0.048492067
# id  673  prediction time  0.053364549
# id  664  prediction time  0.039415745
# id  664  prediction time  0.043162138
# id  508  prediction time  0.050828777
# id  664  prediction time  0.036866431
# id  508  prediction time  0.039998868
# id  620  prediction time  0.033502173
# id  620  prediction time  0.036780494
# id  413  prediction time  0.044700049
# id  592  prediction time  0.049012534
# id  810  prediction time  0.041676102
# id  736  prediction time  0.047022645
# id  736  prediction time  0.038101739
# id  889  prediction time  0.036759713
# id  681  prediction time  0.046697177
# id  763  prediction time  0.049150971
# id  673  prediction time  0.037715022
# id  673  prediction time  0.040698455
# id  673  prediction time  0.045088964
# id  673  prediction time  0.052085294
# id  673  prediction time  0.043377094
# id  508  prediction time  0.049128794
# id  681  prediction time  0.040841686
# id  681  prediction time  0.046847812
# id  714  prediction time  0.04863015
# id  419  prediction time  0.046196668
# id  419  prediction time  0.041787048
# id  798  prediction time  0.043228918
# id  810  prediction time  0.04043424
# id  508  prediction time  0.046708906
# id  508  prediction time  0.040849083
# id  508  prediction time  0.040801791
# id  508  prediction time  0.040362938
# id  508  prediction time  0.042349911
# id  508  prediction time  0.045908076
# id  508  prediction time  0.046613646
# id  508  prediction time  0.049663584
# id  508  prediction time  0.041151997
# id  508  prediction time  0.051775244
# id  508  prediction time  0.047528024
# id  508  prediction time  0.054996077
# id  508  prediction time  0.042996636
# id  508  prediction time  0.037824101
# id  673  prediction time  0.05260046
# id  508  prediction time  0.034986036
# id  508  prediction time  0.041566068
# id  508  prediction time  0.042361742
# id  508  prediction time  0.049907135
# id  508  prediction time  0.040441904
# id  508  prediction time  0.046891781
# id  508  prediction time  0.044038456
# id  508  prediction time  0.052491658
# id  508  prediction time  0.039414095
# id  508  prediction time  0.038431182
# id  508  prediction time  0.042943459
# id  508  prediction time  0.047409435
# id  508  prediction time  0.036138793
# id  508  prediction time  0.035377181
# id  508  prediction time  0.042220857
# id  508  prediction time  0.044339183
# id  508  prediction time  0.042306274
# id  508  prediction time  0.039461126
# id  508  prediction time  0.04729637
# id  508  prediction time  0.039730247
# id  508  prediction time  0.040907172
# id  508  prediction time  0.041761596
# id  508  prediction time  0.053681353
# id  508  prediction time  0.047711318
# id  508  prediction time  0.044927888
# id  508  prediction time  0.044258672
# id  508  prediction time  0.042437323
# id  508  prediction time  0.048740274
# id  508  prediction time  0.040957015
# id  508  prediction time  0.037393692
# id  508  prediction time  0.044789452
# id  508  prediction time  0.051994561
# id  508  prediction time  0.040925454
# id  508  prediction time  0.047670414
# id  508  prediction time  0.039199095
# id  508  prediction time  0.038001243
# id  508  prediction time  0.044369421
# id  508  prediction time  0.052363328
# id  508  prediction time  0.040180273
# id  508  prediction time  0.050017835
# id  508  prediction time  0.046299306
# id  508  prediction time  0.053363789
# id  508  prediction time  0.056429981
# id  508  prediction time  0.035842854
# id  508  prediction time  0.042888032
# id  508  prediction time  0.040342371
# id  508  prediction time  0.040006482
# id  508  prediction time  0.048906317
# id  508  prediction time  0.044068254
# id  508  prediction time  0.047658468
# id  508  prediction time  0.045083371
# id  508  prediction time  0.038268581
# id  508  prediction time  0.054093762
# id  508  prediction time  0.033980278
# id  508  prediction time  0.042863649
# id  508  prediction time  0.047404116
# id  508  prediction time  0.037414661
# id  508  prediction time  0.041350716
# id  508  prediction time  0.046208211
# id  508  prediction time  0.04413265
# id  508  prediction time  0.038410606
# id  508  prediction time  0.040928705
# id  508  prediction time  0.047257382
# id  508  prediction time  0.039722912
# id  508  prediction time  0.042014305
# id  508  prediction time  0.034839826
# id  508  prediction time  0.03995189
# id  508  prediction time  0.046962775
# id  508  prediction time  0.046890512
# id  508  prediction time  0.042619232
# id  508  prediction time  0.035685298
# id  508  prediction time  0.04247773
# id  508  prediction time  0.041113711
# id  508  prediction time  0.04482789
# id  508  prediction time  0.039475023
# id  508  prediction time  0.041500915
# id  508  prediction time  0.035965959
# id  508  prediction time  0.046194775
# id  508  prediction time  0.042618763
# id  508  prediction time  0.045984293
# id  508  prediction time  0.038718015
# id  508  prediction time  0.041268395
# id  508  prediction time  0.041134603
# id  508  prediction time  0.051679663
# id  508  prediction time  0.034577453
# id  508  prediction time  0.033285123
# id  508  prediction time  0.041371333
# id  508  prediction time  0.043753219
# id  508  prediction time  0.041406205
# id  508  prediction time  0.038161002
# id  508  prediction time  0.05102506
# id  508  prediction time  0.045007766
# id  508  prediction time  0.04020261
# id  508  prediction time  0.046407878
# id  508  prediction time  0.048494448
# id  508  prediction time  0.055900601
# id  508  prediction time  0.039502867
# id  508  prediction time  0.043878622
# id  508  prediction time  0.046716357
# id  508  prediction time  0.042237395
# id  508  prediction time  0.040237569
# id  508  prediction time  0.043631099
# id  508  prediction time  0.044287235
# id  508  prediction time  0.050331152
# id  508  prediction time  0.042258026
# id  508  prediction time  0.038189813
# id  508  prediction time  0.041886715
# id  508  prediction time  0.043969639
# id  508  prediction time  0.049480336
# id  508  prediction time  0.045191507
# id  508  prediction time  0.039316389
# id  508  prediction time  0.038942372
# id  508  prediction time  0.0386613
# id  508  prediction time  0.041689223
# id  508  prediction time  0.048130602
# id  508  prediction time  0.036776837
# id  508  prediction time  0.037503145
# id  508  prediction time  0.050648585
# id  508  prediction time  0.043958643
# id  508  prediction time  0.041659631
# id  508  prediction time  0.049695908
# id  508  prediction time  0.03920521
# id  508  prediction time  0.044083993
# id  508  prediction time  0.040575301
# id  508  prediction time  0.053707456
# id  508  prediction time  0.052435154
# id  508  prediction time  0.03977121
# id  508  prediction time  0.048554842
# id  508  prediction time  0.050260554
# id  508  prediction time  0.039732136
# id  508  prediction time  0.03318968
# id  508  prediction time  0.054001324
# id  508  prediction time  0.035754319
# id  508  prediction time  0.040716471
# id  508  prediction time  0.044949613
# id  508  prediction time  0.049848518
# id  508  prediction time  0.042330945
# id  508  prediction time  0.052918669
# id  508  prediction time  0.044528398
# id  508  prediction time  0.047913327
# id  508  prediction time  0.045013537
# id  508  prediction time  0.041099966
# id  508  prediction time  0.045274393
# id  508  prediction time  0.045241259
# id  508  prediction time  0.041355249
# id  508  prediction time  0.051165458
# id  508  prediction time  0.039781463
# id  508  prediction time  0.038726005
# id  508  prediction time  0.051745208
# id  508  prediction time  0.037411877
# id  508  prediction time  0.038852343
# id  508  prediction time  0.036454155
# id  508  prediction time  0.051581617
# id  508  prediction time  0.037890153
# id  508  prediction time  0.045962408
# id  508  prediction time  0.044646467
# id  508  prediction time  0.045896764
# id  508  prediction time  0.061778382
# id  508  prediction time  0.041609578
# id  508  prediction time  0.052539763
# id  508  prediction time  0.049709703
# id  508  prediction time  0.045619916
# id  508  prediction time  0.045211104
# id  508  prediction time  0.034515411
# id  508  prediction time  0.034862852
# id  508  prediction time  0.045313163
# id  508  prediction time  0.037666134
# id  508  prediction time  0.042352233
# id  508  prediction time  0.052752375
# id  508  prediction time  0.05815461
# id  508  prediction time  0.047952598
# id  508  prediction time  0.042343429
# id  508  prediction time  0.052397223
# id  508  prediction time  0.060458327
# id  508  prediction time  0.051356835
# id  508  prediction time  0.054133337
# id  508  prediction time  0.041238276
# id  508  prediction time  0.0463121
# id  508  prediction time  0.077162035
# id  508  prediction time  0.054762779
# id  508  prediction time  0.044797523
# id  508  prediction time  0.054768458
# id  508  prediction time  0.053419446
# id  508  prediction time  0.084694549
# id  508  prediction time  0.045415607
# id  508  prediction time  0.049134794
# id  508  prediction time  0.037256987
# id  508  prediction time  0.040026696
# id  508  prediction time  0.049682495
# id  508  prediction time  0.04727033
# id  508  prediction time  0.041311681
# id  508  prediction time  0.03728465
# id  508  prediction time  0.06203418
# id  508  prediction time  0.038065983
# id  508  prediction time  0.037241135
# id  508  prediction time  0.044378228
# id  508  prediction time  0.048260972
# id  508  prediction time  0.034649148
# id  508  prediction time  0.041884705
# id  508  prediction time  0.039721008
# id  508  prediction time  0.054974306
# id  508  prediction time  0.040805723
# id  508  prediction time  0.051525323
# id  508  prediction time  0.039829423
# id  508  prediction time  0.043283355
# id  508  prediction time  0.045053145
# id  508  prediction time  0.040787853
# id  508  prediction time  0.039360132
# id  508  prediction time  0.037886097
# id  508  prediction time  0.045071171
# id  508  prediction time  0.043742852
# id  508  prediction time  0.041251778
# id  508  prediction time  0.046835075
# id  508  prediction time  0.038600036
# id  508  prediction time  0.041245265
# id  508  prediction time  0.042200152
# id  508  prediction time  0.049412996
# id  508  prediction time  0.042492427
# id  508  prediction time  0.032444741
# id  508  prediction time  0.037021438
# id  508  prediction time  0.038676811
# id  508  prediction time  0.044647356
# id  508  prediction time  0.040642577
# id  508  prediction time  0.040353179
# id  508  prediction time  0.045926174
# id  508  prediction time  0.037701144
# id  508  prediction time  0.044179527
# id  508  prediction time  0.043054082
# id  508  prediction time  0.047824109
# id  508  prediction time  0.036557569
# id  508  prediction time  0.041660546
# id  508  prediction time  0.044277156
# id  508  prediction time  0.041232832
# id  508  prediction time  0.045199164
# id  508  prediction time  0.043335143
# id  508  prediction time  0.04554545
# id  508  prediction time  0.04315046
# id  508  prediction time  0.049956063
# id  508  prediction time  0.038164023
# id  508  prediction time  0.033070427
# id  508  prediction time  0.047702918
# id  508  prediction time  0.050390566
# id  508  prediction time  0.043681284
# id  508  prediction time  0.046776329
# id  508  prediction time  0.039500968
# id  508  prediction time  0.044295501
# id  508  prediction time  0.037017588
# id  508  prediction time  0.05104771
# id  508  prediction time  0.040199268
# id  508  prediction time  0.03820627
# id  508  prediction time  0.041701102
# id  508  prediction time  0.044699925
# id  508  prediction time  0.039476691
# id  508  prediction time  0.039647515
# id  508  prediction time  0.043565579
# id  508  prediction time  0.048577925
# id  508  prediction time  0.039609433
# id  508  prediction time  0.051110329
# id  508  prediction time  0.049151558
# id  508  prediction time  0.044554628
# id  508  prediction time  0.048993966
# id  508  prediction time  0.046403267
# id  508  prediction time  0.039161747
# id  508  prediction time  0.039785253
# id  508  prediction time  0.054711592
# id  508  prediction time  0.041351832
# id  508  prediction time  0.036925755
# id  508  prediction time  0.035230811
# id  508  prediction time  0.039186357
# id  508  prediction time  0.050290308
# id  508  prediction time  0.03977499
# id  508  prediction time  0.043633949
# id  508  prediction time  0.050258634
# id  508  prediction time  0.039383748
# id  508  prediction time  0.054579424
# id  508  prediction time  0.038922074
# id  508  prediction time  0.041579283
# id  508  prediction time  0.042749359
# id  508  prediction time  0.044235763
# id  508  prediction time  0.036045437
# id  508  prediction time  0.042110349
# id  508  prediction time  0.054757905
# id  508  prediction time  0.045388595
# id  508  prediction time  0.047290464
# id  508  prediction time  0.038945742
# id  508  prediction time  0.037667414
# id  508  prediction time  0.038834873
# id  508  prediction time  0.041299676
# id  508  prediction time  0.048247154
# id  508  prediction time  0.041288735
# id  508  prediction time  0.049221447
# id  508  prediction time  0.037895224
# id  508  prediction time  0.037162759
# id  508  prediction time  0.041511705
# id  508  prediction time  0.039586406
# id  508  prediction time  0.051201135
# id  508  prediction time  0.040917189
# id  508  prediction time  0.043320519
# id  508  prediction time  0.046699548
# id  508  prediction time  0.038189044
# id  508  prediction time  0.050695755
# id  508  prediction time  0.043419813
# id  508  prediction time  0.038591378
# id  508  prediction time  0.04174749
# id  508  prediction time  0.052180013
# id  508  prediction time  0.041355627
# id  508  prediction time  0.043137194
# id  508  prediction time  0.045156629
# id  508  prediction time  0.039752236
# id  508  prediction time  0.042184204
# id  508  prediction time  0.046787973
# id  508  prediction time  0.038314718
# id  508  prediction time  0.037409718
# id  810  prediction time  0.032507024
# id  508  prediction time  0.039266656
# id  810  prediction time  0.051353556
# id  508  prediction time  0.040282567
# id  508  prediction time  0.045200733
# id  508  prediction time  0.049231401
# id  508  prediction time  0.033677919
# id  508  prediction time  0.040067778
# id  508  prediction time  0.043377291
# id  508  prediction time  0.051982191
# id  508  prediction time  0.044550686
# id  508  prediction time  0.050768474
# id  508  prediction time  0.043401412
# id  508  prediction time  0.047006618
# id  563  prediction time  0.03740232
# id  418  prediction time  0.04044078
# id  563  prediction time  0.040824307
# id  664  prediction time  0.05279976
# id  782  prediction time  0.036814146
# id  745  prediction time  0.050098536
# id  782  prediction time  0.039479746
# id  782  prediction time  0.038267755
# id  605  prediction time  0.040959922
# id  530  prediction time  0.037958102
# id  480  prediction time  0.046827437
# id  530  prediction time  0.039196557
# id  664  prediction time  0.04208804
# id  530  prediction time  0.050358333
# id  785  prediction time  0.040740237
# id  920  prediction time  0.036236987
# id  920  prediction time  0.040747947
# id  920  prediction time  0.049692091
# id  409  prediction time  0.041097714
# id  605  prediction time  0.040062949
# id  530  prediction time  0.044900181
# id  409  prediction time  0.037353488
# id  920  prediction time  0.04030217
# id  818  prediction time  0.03281226
# id  818  prediction time  0.039245683
# id  818  prediction time  0.04948543
# id  607  prediction time  0.042283083
# id  626  prediction time  0.042670898
# id  862  prediction time  0.051365027
# id  607  prediction time  0.049290407
# id  644  prediction time  0.047722304
# id  818  prediction time  0.042982987
# id  421  prediction time  0.033960859
# id  470  prediction time  0.04912136
# id  785  prediction time  0.040001658
# id  236  prediction time  0.03532647
# id  785  prediction time  0.039687527
# id  785  prediction time  0.050131632
# id  667  prediction time  0.038919703
# id  667  prediction time  0.040584494
# id  747  prediction time  0.037692716
# id  696  prediction time  0.04413626
# id  644  prediction time  0.037097117
# id  667  prediction time  0.040794488
# id  552  prediction time  0.040633411
# id  699  prediction time  0.0443387
# id  467  prediction time  0.038114215
# id  7  prediction time  0.043602081
# id  130  prediction time  0.04207185
# id  7  prediction time  0.050285052
# id  513  prediction time  0.050216092
# id  788  prediction time  0.049852746
# id  665  prediction time  0.04886415
# id  199  prediction time  0.049342533
# id  199  prediction time  0.047005889
# id  669  prediction time  0.051904588
# id  562  prediction time  0.041524514
# id  696  prediction time  0.0468992
# id  696  prediction time  0.04051779
# id  583  prediction time  0.036211248
# id  454  prediction time  0.041380318
# id  816  prediction time  0.037800336
# id  816  prediction time  0.054553329
# id  856  prediction time  0.037281945
# id  856  prediction time  0.040430427
# id  423  prediction time  0.048095757
# id  866  prediction time  0.045587149
# id  423  prediction time  0.049297471
# id  491  prediction time  0.039520026

# %%
# Out:
# [1 1 1]
# [[1 1 1]]
